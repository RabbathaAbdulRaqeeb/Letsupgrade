# %%
#  Assignment 3  #
# Python function for checking weather the given number is prime or not #

# %%
def is_prime(num):
    for i in range(2,num):
        if num%i==0:
            print(num," is not a prime number")
            break
        else:
            print(num," is a prime number ")
            break

is_prime(7)
# Out:
# 7  is a prime number
