# %%
# Assignment 1#
#List#

# %%
a =[1,5,4,3,8,6,70]
a
# Out:
# [1, 5, 4, 3, 8, 6, 70]

# %%
a.append(11)

# %%
a
# Out:
# [1, 3, 4, 5, 6, 8, 70, 11]

# %%
a. insert(5,333)
a
# Out:
# [1, 3, 4, 5, 6, 333, 8, 70, 11]

# %%
a. sort()
a
# Out:
# [1, 3, 4, 5, 6, 8, 11, 70, 333]

# %%
b = a. copy()
b
# Out:
# [1, 3, 4, 5, 6, 8, 11, 70, 333]

# %%
b.clear()
b
# Out:
# []

# %%
#  Dictionary #

# %%
dic = {"Name":"Abdul","Language":"python","school":"Letsupgrade"}
dic
# Out:
# {'Name': 'Abdul', 'Language': 'python', 'school': 'Letsupgrade'}

# %%
dic.keys()
# Out:
# dict_keys(['Name', 'Language', 'school'])

# %%
dic. values()
# Out:
# dict_values(['Abdul', 'python', 'Letsupgrade'])

# %%
dic. get("Name")
# Out:
# 'Abdul'

# %%
dic.clear()

# %%
dic
# Out:
# {}
