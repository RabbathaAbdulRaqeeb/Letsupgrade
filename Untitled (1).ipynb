# %%
print("Welcome to the 'AIR INDIA'")

a = int(input("Enter the range of Altitude :"))

if a<=1000:
    print("Safe to Land ")
elif 1000<a and a<=5000:
    print("Bring down to 10000")
elif a>5000:
    print("Turn Around ")
# Out:
# Welcome to the 'AIR INDIA'
# Enter the range of Altitude : 5500
# Turn Around
